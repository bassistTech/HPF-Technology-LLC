# %% [markdown]
# # Wiring to the HPF-Pre boards
#
# Francis Deck
#
# 4-7-2024
#
# ## Overview
#
# This document (under construction) describes the wiring of the HPF-Pre boards. It's intended for those who would like to put an HPF-Pre into a custom enclosure.
#
# In the future, this is also where I'll discuss Mods.

# %% [markdown]
# ## Series 2M
# ![image.png](attachment:ed649170-5e2f-4cce-9095-a61ec18ecab8.png)
#
# **Red and black** go to the 9-V battery snap
#
# **Pin 1 (Green)** = Ground
#
# **Pin 2 (Orange)** = Negative terminal of battery snap
#
# **Pin 3 (Brown)** = Output of the circuit
#
# **Pin 4 (Blue)** = Input to the circuit
#
# ![image.png](attachment:aea1f7f8-a6a4-47b6-b90b-01062aeb0203.png)

# %% [markdown]
# Series 2M does not support a DC power jack, because the output of typical adapters is not clean enough, and power supply noise is coupled to the signal path of the audio circuit. The battery snap connected directly to the circuit board. The negative terminal of the battery passes directly through to the Battery terminal (orange wire) which can be connected to the ring terminal of the output connector. When a 2-conductor plug is inserted into this connector, it connects the Ring and Sleeve (ground) terminals together, and completes the battery circuit.

# %% [markdown]
# ## Series 3
#
# ![image.png](attachment:13393cab-99c1-4cdd-8eeb-538073f93c94.png)
#
# **Pin 1 (Green)** = Ground
#
# **Pin 2 (Orange)** = Power input, nominally 9 V
#
# **Pin 3 (Brown)** = Output of the circuit
#
# **Pin 4 (Blue)** = Input to the circuit
#
# ![image.png](attachment:9ede9828-41d1-450d-8ac4-f4fca5bef370.png)

# %% [markdown]
# Series 3 is a bit more complicated because it supports a power jack. This wiring scheme is as old as effects pedals.
#
# With nothing plugged into the power jack, the positive terminal of the battery is conected directly to the power input of the circuit board. The negative terminal is connected to the ring terminal of the output jack. When a 2-conductor plug is inserted into the output jack, it completes the battery circuit, just like the Series 2M circuit.
#
# For custom wiring, you can omit the power jack by connecting the orange wire directly to the positive terminal of the battery snap.

# %% [markdown]
# ## Series 3 "Mini"
#
# ![image.png](attachment:97288691-4b9f-4880-933e-05a4cb60590b.png)
#
# **Pin 1 (Green)** = Ground
#
# **Pin 2 (Orange)** = Power input, nominally 9 V
#
# **Pin 3 (Brown)** = Output of the circuit
#
# **Pin 4 (Blue)** = Input to the circuit
#
# ![image.png](attachment:d9f6338b-ba55-4544-9187-938d92e19019.png)

# %% [markdown]
# The Mini is the simplest because it only supports external power.

# %% [markdown]
# ## Possible modifications
#
# ### The op amp chip
#
# The Series 3 circuit uses a very high performance op amp chip, designed for high performance audio circuits, the OPA1654. I've used it since it was introduced by Burr-Brown, now Texas Instruments. Its only drawback is that it draws a fair amount of current, 2 mA per channel or 8 mA for the entire chip.
